# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('dataset.csv')
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
data=data.drop(columns='Unnamed: 0')
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
data['Company_Name']=data['Name'].str.split(' ').str.get(0)

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price Company_Name
# 0        NaN   1.75       Maruti
# ...

# %%
data['Name']=data['Name'].str.split(' ').str.slice(0,4).str.join(' ')

# %%
data.head()
# Out:
#                      Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0      Maruti Wagon R LXI      Mumbai  2010              72000       CNG
# 1  Hyundai Creta 1.6 CRDi        Pune  2015              41000    Diesel
# 2            Honda Jazz V     Chennai  2011              46000    Petrol
# 3       Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4         Audi A4 New 2.0  Coimbatore  2013              40670    Diesel
#
#   Transmission Owner_Type     Mileage   Engine      Power  Seats  New_Price  \
# 0       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0        NaN
# 1       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0        NaN
# 2       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0  8.61 Lakh
# 3       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0        NaN
# 4    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0        NaN
#
#    Price Company_Name
# 0   1.75       Maruti
# 1  12.50      Hyundai
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
#  13  Company_Name       6019 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 658.5+ KB

# %%
data['Year'].unique()
# Out:
# array([2010, 2015, 2011, 2012, 2013, 2016, 2018, 2014, 2017, 2007, 2009,
#        2008, 2019, 2006, 2005, 2004, 2002, 2000, 2003, 1999, 2001, 1998],
#       dtype=int64)

# %%
data['Fuel_Type'].unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['Owner_Type'].unique()
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
data[data['Owner_Type']=='Fourth & Above']
# Out:
#                         Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 29       Toyota Innova 2.5 V      Mumbai  2007             262000    Diesel
# 885   Maruti Grand Vitara AT     Chennai  2008              77000    Petrol
# 1081  Hyundai i20 1.2 Sportz   Bangalore  2010              61000    Petrol
# 1699  Ford Endeavour 4x2 XLT        Pune  2007              90000    Diesel
# 2988    Toyota Innova 2.5 G4     Chennai  2005             240000    Diesel
# 3368  Maruti Swift Ldi BSIII        Pune  2009              80000    Diesel
# 3404    Maruti Swift 1.3 VXi      Jaipur  2006             125000    Petrol
# 4148     Ford Ikon 1.3 Flair  Coimbatore  2008              59833    Petrol
# 5647  Toyota Qualis Fleet A3      Mumbai  2001             227000    Diesel
#
#      Transmission      Owner_Type    Mileage   Engine      Power  Seats  \
# 29         Manual  Fourth & Above  12.8 kmpl  2494 CC    102 bhp    7.0
# ...

# %%
data['Owner_Type']=data['Owner_Type'].str.split('&').str.get(0).str.strip()

# %%
data['Owner_Type'].unique()
# Out:
# array(['First', 'Second', 'Fourth', 'Third'], dtype=object)

# %%
data['Mileage'].unique()
# Out:
# array(['26.6 km/kg', '19.67 kmpl', '18.2 kmpl', '20.77 kmpl', '15.2 kmpl',
#        '21.1 km/kg', '23.08 kmpl', '11.36 kmpl', '20.54 kmpl',
#        '22.3 kmpl', '21.56 kmpl', '16.8 kmpl', '25.2 kmpl', '12.7 kmpl',
#        '0.0 kmpl', '13.5 kmpl', '25.8 kmpl', '28.4 kmpl', '20.45 kmpl',
#        '14.84 kmpl', '22.69 kmpl', '23.65 kmpl', '13.53 kmpl',
#        '18.5 kmpl', '14.4 kmpl', '20.92 kmpl', '17.5 kmpl', '12.8 kmpl',
#        '19.01 kmpl', '14.53 kmpl', '11.18 kmpl', '12.4 kmpl',
#        '16.09 kmpl', '14.0 kmpl', '24.3 kmpl', '18.15 kmpl', '11.74 kmpl',
#        '22.07 kmpl', '19.7 kmpl', '25.4 kmpl', '25.32 kmpl', '14.62 kmpl',
#        '14.28 kmpl', '14.9 kmpl', '11.25 kmpl', '24.4 kmpl', '16.55 kmpl',
#        '17.11 kmpl', '22.9 kmpl', '17.8 kmpl', '18.9 kmpl', '15.04 kmpl',
#        '25.17 kmpl', '20.36 kmpl', '13.29 kmpl', '13.68 kmpl',
#        '20.0 kmpl', '15.8 kmpl', '25.0 kmpl', '16.4 kmpl', '24.52 kmpl',
# ...

# %%
data['Mileage']=data['Mileage'].str.split(' ').str.get(0).astype(float)

# %%
data=data[~data['Mileage'].isna()]

# %%
data=data[data['Mileage']!=0.0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5949 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5949 non-null   object
#  1   Location           5949 non-null   object
#  2   Year               5949 non-null   int64
#  3   Kilometers_Driven  5949 non-null   int64
#  4   Fuel_Type          5949 non-null   object
#  5   Transmission       5949 non-null   object
#  6   Owner_Type         5949 non-null   object
#  7   Mileage            5949 non-null   float64
#  8   Engine             5924 non-null   object
#  9   Power              5924 non-null   object
#  10  Seats              5919 non-null   float64
#  11  New_Price          819 non-null    object
#  12  Price              5949 non-null   float64
#  13  Company_Name       5949 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 697.1+ KB

# %%
data['Engine'].unique()
# Out:
# array(['998 CC', '1582 CC', '1199 CC', '1248 CC', '1968 CC', '814 CC',
#        '1461 CC', '2755 CC', '1598 CC', '1462 CC', '1497 CC', '2179 CC',
#        '2477 CC', '1498 CC', '2143 CC', '1995 CC', '1984 CC', '1197 CC',
#        '2494 CC', '1798 CC', '2696 CC', '2698 CC', '1061 CC', '1198 CC',
#        '2987 CC', '796 CC', '624 CC', '1999 CC', '1991 CC', '2694 CC',
#        '1120 CC', '2498 CC', '799 CC', '2393 CC', '1399 CC', '1796 CC',
#        '2148 CC', '1396 CC', '4806 CC', '1998 CC', '1193 CC', '1086 CC',
#        '2982 CC', '1493 CC', '2967 CC', '2993 CC', '1196 CC', '1799 CC',
#        '2497 CC', '2354 CC', '1373 CC', '2996 CC', '1591 CC', '2894 CC',
#        '5461 CC', '1595 CC', '936 CC', '1997 CC', '1896 CC', '1390 CC',
#        '1364 CC', nan, '2199 CC', '993 CC', '999 CC', '1405 CC',
#        '2956 CC', '1794 CC', '995 CC', '2496 CC', '1599 CC', '2400 CC',
#        '1495 CC', '2523 CC', '793 CC', '4134 CC', '1596 CC', '1950 CC',
# ...

# %%
data=data[~data['Engine'].isna()]

# %%
data['Engine']
# Out:
# 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 6014    1248 CC
# 6015    1120 CC
# 6016    2498 CC
# 6017     998 CC
# 6018     936 CC
# Name: Engine, Length: 5924, dtype: object

# %%
data['Engine']=data['Engine'].str.split(' ').str.get(0).astype(int)

# %%
data
# Out:
#                         Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0         Maruti Wagon R LXI      Mumbai  2010              72000       CNG
# 1     Hyundai Creta 1.6 CRDi        Pune  2015              41000    Diesel
# 2               Honda Jazz V     Chennai  2011              46000    Petrol
# 3          Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4            Audi A4 New 2.0  Coimbatore  2013              40670    Diesel
# ...                      ...         ...   ...                ...       ...
# 6014        Maruti Swift VDI       Delhi  2014              27365    Diesel
# 6015  Hyundai Xcent 1.1 CRDi      Jaipur  2015             100000    Diesel
# 6016   Mahindra Xylo D4 BSIV      Jaipur  2012              55000    Diesel
# 6017      Maruti Wagon R VXI     Kolkata  2013              46000    Petrol
# 6018   Chevrolet Beat Diesel   Hyderabad  2011              47000    Diesel
#
# ...

# %%
data['Power']
# Out:
# 0       58.16 bhp
# 1       126.2 bhp
# 2        88.7 bhp
# 3       88.76 bhp
# 4       140.8 bhp
#           ...
# 6014       74 bhp
# 6015       71 bhp
# 6016      112 bhp
# 6017     67.1 bhp
# 6018     57.6 bhp
# Name: Power, Length: 5924, dtype: object

# %%
data[~data['Power'].isna()]
# Out:
#                         Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0         Maruti Wagon R LXI      Mumbai  2010              72000       CNG
# 1     Hyundai Creta 1.6 CRDi        Pune  2015              41000    Diesel
# 2               Honda Jazz V     Chennai  2011              46000    Petrol
# 3          Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4            Audi A4 New 2.0  Coimbatore  2013              40670    Diesel
# ...                      ...         ...   ...                ...       ...
# 6014        Maruti Swift VDI       Delhi  2014              27365    Diesel
# 6015  Hyundai Xcent 1.1 CRDi      Jaipur  2015             100000    Diesel
# 6016   Mahindra Xylo D4 BSIV      Jaipur  2012              55000    Diesel
# 6017      Maruti Wagon R VXI     Kolkata  2013              46000    Petrol
# 6018   Chevrolet Beat Diesel   Hyderabad  2011              47000    Diesel
#
# ...

# %%
data['Power'].unique()
# Out:
# array(['58.16 bhp', '126.2 bhp', '88.7 bhp', '88.76 bhp', '140.8 bhp',
#        '55.2 bhp', '63.1 bhp', '171.5 bhp', '103.6 bhp', '74 bhp',
#        '103.25 bhp', '116.3 bhp', '187.7 bhp', '175.56 bhp', '98.6 bhp',
#        '83.8 bhp', '167.62 bhp', '190 bhp', '88.5 bhp', '177.01 bhp',
#        '80 bhp', '67.1 bhp', '102 bhp', '108.45 bhp', '138.1 bhp',
#        '184 bhp', '179.5 bhp', '103.5 bhp', '64 bhp', '82 bhp',
#        '254.8 bhp', '73.9 bhp', '46.3 bhp', '37.5 bhp', '77 bhp',
#        '82.9 bhp', '149.92 bhp', '138.03 bhp', '112.2 bhp', '163.7 bhp',
#        '71 bhp', '105 bhp', '174.33 bhp', '75 bhp', '103.2 bhp',
#        '53.3 bhp', '78.9 bhp', '147.6 bhp', '147.8 bhp', '68 bhp',
#        '186 bhp', '170 bhp', '69 bhp', '140 bhp', '78 bhp', '500 bhp',
#        '108.5 bhp', '86.8 bhp', '187.74 bhp', 'null bhp', '132 bhp',
#        '86.7 bhp', '73.94 bhp', '117.3 bhp', '218 bhp', '168.5 bhp',
#        '89.84 bhp', '110 bhp', '90 bhp', '82.85 bhp', '67 bhp',
# ...

# %%
data['Power']=data['Power'].str.split(' ').str.get(0)

# %%
mean=data[data['Power']!='null']
m=mean['Power'].astype(float).mean()
m
# Out:
# 113.13736355859707

# %%
data['Power']=data['Power'].replace('null',m)

# %%
data['Power']=data['Power'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5924 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5924 non-null   object
#  1   Location           5924 non-null   object
#  2   Year               5924 non-null   int64
#  3   Kilometers_Driven  5924 non-null   int64
#  4   Fuel_Type          5924 non-null   object
#  5   Transmission       5924 non-null   object
#  6   Owner_Type         5924 non-null   object
#  7   Mileage            5924 non-null   float64
#  8   Engine             5924 non-null   int32
#  9   Power              5924 non-null   float64
#  10  Seats              5919 non-null   float64
#  11  New_Price          819 non-null    object
#  12  Price              5924 non-null   float64
#  13  Company_Name       5924 non-null   object
# dtypes: float64(4), int32(1), int64(2), object(7)
# memory usage: 671.1+ KB

# %%
data['Seats'].unique()
# Out:
# array([ 5.,  7.,  8.,  4.,  6.,  2., 10.,  9., nan,  0.])

# %%
data=data[data['Seats']!=0.]

# %%
data=data[~data['Seats'].isna()]

# %%
data['Seats'].unique()
# Out:
# array([ 5.,  7.,  8.,  4.,  6.,  2., 10.,  9.])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5918 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5918 non-null   object
#  1   Location           5918 non-null   object
#  2   Year               5918 non-null   int64
#  3   Kilometers_Driven  5918 non-null   int64
#  4   Fuel_Type          5918 non-null   object
#  5   Transmission       5918 non-null   object
#  6   Owner_Type         5918 non-null   object
#  7   Mileage            5918 non-null   float64
#  8   Engine             5918 non-null   int32
#  9   Power              5918 non-null   float64
#  10  Seats              5918 non-null   float64
#  11  New_Price          819 non-null    object
#  12  Price              5918 non-null   float64
#  13  Company_Name       5918 non-null   object
# dtypes: float64(4), int32(1), int64(2), object(7)
# memory usage: 670.4+ KB

# %%
data=data.drop(columns='New_Price')

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  5918.000000       5.918000e+03  5918.000000  5918.000000  5918.000000
# mean   2013.424637       5.851814e+04    18.352731  1619.999662   113.139583
# std       3.208118       9.186641e+04     4.180405   598.149133    53.474654
# min    1998.000000       1.710000e+02     6.400000   624.000000    34.200000
# 25%    2012.000000       3.385575e+04    15.300000  1198.000000    76.800000
# 50%    2014.000000       5.300000e+04    18.200000  1493.000000    98.600000
# 75%    2016.000000       7.267100e+04    21.100000  1982.500000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  5918.000000  5918.000000
# mean      5.281176     9.477273
# std       0.805185    11.158216
# min       2.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.650000
# 75%       5.000000     9.915000
# ...

# %%
data[data['Price'] >100 ]
# Out:
#                             Name   Location  Year  Kilometers_Driven  \
# 4079      Land Rover Range Rover  Hyderabad  2017              25000
# 5781  Lamborghini Gallardo Coupe      Delhi  2011               6500
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine  Power  Seats  Price  \
# 4079    Diesel    Automatic      First    13.33    2993  255.0    5.0  160.0
# 5781    Petrol    Automatic      Third     6.40    5204  560.0    2.0  120.0
#
#      Company_Name
# 4079         Land
# 5781  Lamborghini

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5918 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5918 non-null   object
#  1   Location           5918 non-null   object
#  2   Year               5918 non-null   int64
#  3   Kilometers_Driven  5918 non-null   int64
#  4   Fuel_Type          5918 non-null   object
#  5   Transmission       5918 non-null   object
#  6   Owner_Type         5918 non-null   object
#  7   Mileage            5918 non-null   float64
#  8   Engine             5918 non-null   int32
#  9   Power              5918 non-null   float64
#  10  Seats              5918 non-null   float64
#  11  Price              5918 non-null   float64
#  12  Company_Name       5918 non-null   object
# dtypes: float64(4), int32(1), int64(2), object(6)
# memory usage: 624.2+ KB

# %%
data.to_csv('CleanedData.csv',index=0)

# %%
df=pd.read_csv('CleanedData.csv')
df
# Out:
#                         Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0         Maruti Wagon R LXI      Mumbai  2010              72000       CNG
# 1     Hyundai Creta 1.6 CRDi        Pune  2015              41000    Diesel
# 2               Honda Jazz V     Chennai  2011              46000    Petrol
# 3          Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4            Audi A4 New 2.0  Coimbatore  2013              40670    Diesel
# ...                      ...         ...   ...                ...       ...
# 5913        Maruti Swift VDI       Delhi  2014              27365    Diesel
# 5914  Hyundai Xcent 1.1 CRDi      Jaipur  2015             100000    Diesel
# 5915   Mahindra Xylo D4 BSIV      Jaipur  2012              55000    Diesel
# 5916      Maruti Wagon R VXI     Kolkata  2013              46000    Petrol
# 5917   Chevrolet Beat Diesel   Hyderabad  2011              47000    Diesel
#
# ...

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  5918.000000       5.918000e+03  5918.000000  5918.000000  5918.000000
# mean   2013.424637       5.851814e+04    18.352731  1619.999662   113.139583
# std       3.208118       9.186641e+04     4.180405   598.149133    53.474654
# min    1998.000000       1.710000e+02     6.400000   624.000000    34.200000
# 25%    2012.000000       3.385575e+04    15.300000  1198.000000    76.800000
# 50%    2014.000000       5.300000e+04    18.200000  1493.000000    98.600000
# 75%    2016.000000       7.267100e+04    21.100000  1982.500000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  5918.000000  5918.000000
# mean      5.281176     9.477273
# std       0.805185    11.158216
# min       2.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.650000
# 75%       5.000000     9.915000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5918 entries, 0 to 5917
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5918 non-null   object
#  1   Location           5918 non-null   object
#  2   Year               5918 non-null   int64
#  3   Kilometers_Driven  5918 non-null   int64
#  4   Fuel_Type          5918 non-null   object
#  5   Transmission       5918 non-null   object
#  6   Owner_Type         5918 non-null   object
#  7   Mileage            5918 non-null   float64
#  8   Engine             5918 non-null   int64
#  9   Power              5918 non-null   float64
#  10  Seats              5918 non-null   float64
#  11  Price              5918 non-null   float64
#  12  Company_Name       5918 non-null   object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 601.2+ KB

# %% [markdown]
# # Visualization

# %% [markdown]
# # 1. Price Distribution

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=30, kde=True)
plt.title('Distribution of Car Prices')
plt.xlabel('Price (in lakhs)')
plt.ylabel('Number of Cars')
plt.show()

# %% [markdown]
# # 2. Price vs. Mileage

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Mileage', y='Price', data=df)
plt.title('Price vs. Mileage')
plt.xlabel('Mileage (kmpl)')
plt.ylabel('Price (in lakhs)')
plt.show()

# %% [markdown]
# # 3. Price by Fuel Type

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Fuel_Type', y='Price', data=df)
plt.title('Car Prices by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Price (in lakhs)')
plt.show()

# %% [markdown]
# # 4. Engine Size vs. Price

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Engine', y='Price', data=df)
plt.title('Engine Size vs. Price')
plt.xlabel('Engine (CC)')
plt.ylabel('Price (in lakhs)')
plt.show()

# %% [markdown]
# # 5. Company-wise Car Count

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Name', data=df, order=df['Name'].value_counts().index)
plt.title('Number of Cars by Company')
plt.xlabel('Number of Cars')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Model

# %%
x=df.drop(columns=['Price','Seats'])

# %%
x
# Out:
#                         Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0         Maruti Wagon R LXI      Mumbai  2010              72000       CNG
# 1     Hyundai Creta 1.6 CRDi        Pune  2015              41000    Diesel
# 2               Honda Jazz V     Chennai  2011              46000    Petrol
# 3          Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4            Audi A4 New 2.0  Coimbatore  2013              40670    Diesel
# ...                      ...         ...   ...                ...       ...
# 5791        Maruti Swift VDI       Delhi  2014              27365    Diesel
# 5792  Hyundai Xcent 1.1 CRDi      Jaipur  2015             100000    Diesel
# 5793   Mahindra Xylo D4 BSIV      Jaipur  2012              55000    Diesel
# 5794      Maruti Wagon R VXI     Kolkata  2013              46000    Petrol
# 5795   Chevrolet Beat Diesel   Hyderabad  2011              47000    Diesel
#
# ...

# %%
y=df['Price']
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 5791     4.75
# 5792     4.00
# 5793     2.90
# 5794     2.65
# 5795     2.50
# Name: Price, Length: 5796, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
x_train,x_text,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5796 entries, 0 to 5795
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5796 non-null   object
#  1   Location           5796 non-null   object
#  2   Year               5796 non-null   int64
#  3   Kilometers_Driven  5796 non-null   int64
#  4   Fuel_Type          5796 non-null   object
#  5   Transmission       5796 non-null   object
#  6   Owner_Type         5796 non-null   object
#  7   Mileage            5796 non-null   float64
#  8   Engine             5796 non-null   int64
#  9   Power              5796 non-null   float64
#  10  Company_Name       5796 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 543.4+ KB

# %%
ohe=OneHotEncoder()
ohe.fit(x[['Name','Location','Fuel_Type','Transmission','Owner_Type','Company_Name']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Ambassador Classic Nova Diesel', 'Audi A3 35 TDI',
#         'Audi A4 1.8 TFSI', ..., 'Volvo XC60 D5',
#         'Volvo XC60 D5 Inscription', 'Volvo XC90 2007-2015 D5'],
#        dtype=object),
#  array(['Ahmedabad', 'Bangalore', 'Chennai', 'Coimbatore', 'Delhi',
#         'Hyderabad', 'Jaipur', 'Kochi', 'Kolkata', 'Mumbai', 'Pune'],
#        dtype=object),
#  array(['CNG', 'Diesel', 'LPG', 'Petrol'], dtype=object),
#  array(['Automatic', 'Manual'], dtype=object),
#  array(['First', 'Fourth', 'Second', 'Third'], dtype=object),
#  array(['Ambassador', 'Audi', 'BMW', 'Bentley', 'Chevrolet', 'Datsun',
#         'Fiat', 'Force', 'Ford', 'Honda', 'Hyundai', 'ISUZU', 'Isuzu',
#         'Jaguar', 'Jeep', 'Lamborghini', 'Land', 'Mahindra', 'Maruti',
#         'Mercedes-Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Porsche',
#         'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#        dtype=object)]

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Name','Location','Fuel_Type','Transmission','Owner_Type','Company_Name']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Ambassador Classic Nova Diesel', 'Audi A3 35 TDI',
#        'Audi A4 1.8 TFSI', ..., 'Volvo XC60 D5',
#        'Volvo XC60 D5 Inscription', 'Volvo XC90 2007-2015 D5'],
#       dtype=object),
#                                                                             array(['Ahmedabad', 'Bangalore', 'Chennai', 'Coimbatore', 'Delhi',
#        'Hyd...
#        'Fiat', 'Force', 'Ford', 'Honda', 'Hyundai', 'ISUZU', 'Isuzu',
#        'Jaguar', 'Jeep', 'Lamborghini', 'Land', 'Mahindra', 'Maruti',
#        'Mercedes-Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Porsche',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object)]),
#                                                   ['Name', 'Location',
# ...

# %%
y_pred=pipe.predict(x_text)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8174924981983918

# %%
score=[]
for i in range(1000):
    X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,Y_train)
    y_pred=pipe.predict(X_test)
    score.append(r2_score(Y_test,y_pred))

# %%
max(score)
# Out:
# 0.8478782919387537

# %%
np.argmax(score)
# Out:
# 379

# %%
score[np.argmax(score)]
# Out:
# 0.8478782919387537

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\91930\AppData\Local\Temp\ipykernel_21300\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=np.argmax(score))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,Y_train)
y_pred=pipe.predict(X_test)
print(r2_score(Y_test,y_pred))
# Out:
# 0.8478782919387537

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
df.head(3)
# Out:
#                      Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0      Maruti Wagon R LXI   Mumbai  2010              72000       CNG
# 1  Hyundai Creta 1.6 CRDi     Pune  2015              41000    Diesel
# 2            Honda Jazz V  Chennai  2011              46000    Petrol
#
#   Transmission Owner_Type  Mileage  Engine   Power  Seats  Price Company_Name
# 0       Manual      First    26.60     998   58.16    5.0   1.75       Maruti
# 1       Manual      First    19.67    1582  126.20    5.0  12.50      Hyundai
# 2       Manual      First    18.20    1199   88.70    5.0   4.50        Honda

# %%
pipe.predict(pd.DataFrame([['Honda Jazz V','Chennai',2011,46000,'Petrol','Manual','First',18.20,1199,88.70,'Honda']],columns=['Name','Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine','Power','Company_Name']))
# Out:
# array([1.52402969])
